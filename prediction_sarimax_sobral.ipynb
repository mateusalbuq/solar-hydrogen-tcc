# %% [markdown]
# # MBA em Ciência de Dados - TCC
# # Predição da Radiação Solar para Produção de Hidrogênio Verde: Análise comparativa de métodos de Aprendizado de Máquina
#
# ## Modelagem e Predição
# **Material Produzido por:** Mateus Vasconcelos Albuquerque
#
# **Cemeai - ICMC/USP São Carlos**
#
#
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## **CRISP-DS**

# %% [markdown]
# ![CRISP-DS.png](data:image/png;base64,...)

# %%
# from google.colab import drive
# import os

# # Monta o Google Drive
# drive.mount('/content/drive')

# # Define o caminho da pasta 'Projetos'
# projetos_path = '/content/drive/My Drive/MBA/TCC/Projeto'

# # Define o diretório de trabalho para a pasta 'Projetos'
# if os.path.exists(projetos_path):
#     os.chdir(projetos_path)
#     print(f"Diretório alterado para: {projetos_path}")
# else:
#     print(f"A pasta 'Projetos' não foi encontrada em: {projetos_path}")

# %% [markdown]
# ## **3. Preparação dos Dados**

# %% [markdown]
# ### 3.1. Import dos dados pré-processados

# %%
import pandas as pd
from pandas.plotting import lag_plot
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import yaml
import os

# %%
# Leitura do arquivo de configuração

# folder para carregar os config files
CONFIG_PATH = "config/"

# Função para carregar os dados
def load_config(config_name):
    with open(os.path.join(CONFIG_PATH, config_name)) as file:
        config = yaml.safe_load(file)

    return config

# %%
config = load_config("data_preprocessing_config_sobral.yaml")

# mostrar todas as colunas
pd.set_option("display.max_columns", None)

# %%
# Leitura dos dados a partir do CSV
codigo_wmo = config["input_data_parameters"]["codigo_wmo"]
estacao = config["input_data_parameters"]["estacao"]

input_dir = config["output_directory_preprocessing"]

filepath = f"{input_dir}/preprocessed_data_{codigo_wmo}_{estacao}.csv"

data = pd.read_csv(
    filepath,
    index_col=0,
)

# # remove last 5 columns
# data = data.iloc[:, :-5]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43824 entries, 2015-01-01 00:00:00 to 2019-12-31 23:00:00
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   precipitacao_total_horario                 43824 non-null  float64
#  1   pressao_atmosferica_nivel_estacao_horaria  43824 non-null  float64
#  2   temperatura_ar_bulbo_seco_horaria          43824 non-null  float64
#  3   umidade_relativa_ar_horaria                43824 non-null  float64
#  4   vento_direcao_horaria                      43824 non-null  float64
#  5   vento_rajada_maxima                        43824 non-null  float64
#  6   vento_velocidade_horaria                   43824 non-null  float64
#  7   radiacao_global                            43824 non-null  float64
#  8   year                                       43824 non-null  int64
#  9   hora                                       43824 non-null  int64
#  10  mes                                        43824 non-null  int64
#  11  semana                                     43824 non-null  int64
#  12  dia_ano                                    43824 non-null  int64
# dtypes: float64(8), int64(5)
# memory usage: 4.7+ MB

# %%
# defining target (Y) and explanatory variable (X)
predictor_variable = ["temperatura_ar_bulbo_seco_horaria"]
target_variable = ["radiacao_global"]

X = data[predictor_variable]
Y = data[target_variable]

# X = data.iloc[:, predictor_variable]
# Y = data.iloc[:, target_variables]

# %% [markdown]
# #### 3.2.3 Divisão em Treino e Teste

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as mae
from sklearn.ensemble import RandomForestRegressor

# train/test split
X_tr, X_ts, Y_tr, Y_ts = train_test_split(X, Y, test_size=0.3, shuffle=False)

# %% [markdown]
# #### 3.2.4. Min-Max Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# Inicializar o Min-Max Scaler
scaler = MinMaxScaler()

# Ajustar o scaler nos dados de treino e transformar os dados de treino
X_tr_scaled = pd.DataFrame(scaler.fit_transform(X_tr), index=X_tr.index, columns=X_tr.columns)

# Transformar os dados de teste (usando o scaler ajustado nos dados de treino)
X_ts_scaled = pd.DataFrame(scaler.transform(X_ts), index=X_ts.index, columns=X_ts.columns)

# %%
# Ajustar o scaler nos dados de treino da variável alvo
scaler_y = MinMaxScaler()

# Escalar Y_tr e Y_ts
Y_tr_scaled = pd.DataFrame(scaler_y.fit_transform(Y_tr), index=Y_tr.index, columns=Y_tr.columns)
Y_ts_scaled = pd.DataFrame(scaler_y.transform(Y_ts), index=Y_ts.index, columns=Y_ts.columns)
# Out:
# O Kernel deu pane ao executar o código na célula atual ou em uma célula anterior.
#
# Analise o código nas células para identificar uma possível causa da pane.
#
# Clique <a href='https://aka.ms/vscodeJupyterKernelCrash'>aqui</a> para obter mais informações.
#
# Consulte Jupyter <a href='command:jupyter.viewOutput'>log</a> para obter mais detalhes.

# %%
# Previsão usando auto-arima
import pmdarima as pm

# SARIMAX Model
SARIMAX_model = pm.auto_arima(
    Y_tr_scaled,
    exogenous=X_tr_scaled,
    start_p=0,
    start_q=0,
    test="adf",
    max_p=3,
    max_q=3,
    m=24,
    seasonal=True,
    trace=True,
    error_action="ignore",
    suppress_warnings=True,
    stepwise=True,
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(1,0,1)[24] intercept   : AIC=inf, Time=159.22 sec
#  ARIMA(0,0,0)(0,0,0)[24] intercept   : AIC=6386.121, Time=4.21 sec
#  ARIMA(1,0,0)(1,0,0)[24] intercept   : AIC=-63484.154, Time=119.65 sec
#  ARIMA(0,0,1)(0,0,1)[24] intercept   : AIC=-37067.706, Time=78.83 sec
#  ARIMA(0,0,0)(0,0,0)[24]             : AIC=19899.323, Time=1.30 sec
#  ARIMA(1,0,0)(0,0,0)[24] intercept   : AIC=-48202.230, Time=2.12 sec

# %%
SARIMAX_model.summary()

# %%
predito_sarimax = SARIMAX_model.predict(
    n_periods=len(Y_ts_scaled), exogenous=X_ts_scaled
)

# %%
# Plots dos resultados para 7 dias de teste
plt.rcParams["figure.figsize"] = [18, 6]
Y_ts_scaled.plot(legend=True, label="Teste")
predito_sarimax.plot(legend=True, label="Previsão SARIMAX")

plt.show()

# %%
# Erros absolutos médios
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

mae_sarima = mean_absolute_error(Y_ts_scaled, predito_sarimax)
rmse_sarima = np.sqrt(mean_squared_error(Y_ts_scaled["radiacao_global"], predito_sarimax))
mape_sarima = mean_absolute_percentage_error(Y_ts_scaled["radiacao_global"], predito_sarimax)

# %% [markdown]
# ## **4. Treinamento (Modelagem)**

# %%
# fitting a RF model
model = RandomForestRegressor()
model.fit(X_tr_scaled, Y_tr_scaled.to_numpy().ravel())
# Out:
# RandomForestRegressor()

# %%
# from joblib import dump

# # Salvar o modelo treinado em um arquivo
# dump(model, "random_forest_model.joblib")

# print("Modelo salvo como 'random_forest_model.joblib'.")
# Out:
# Modelo salvo como 'random_forest_model.joblib'.

# %%
from joblib import load

# Carregar o modelo salvo
model = load("random_forest_model.joblib")

print("Modelo carregado com sucesso.")
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:348: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeRegressor from version 1.6.0 when using version 1.3.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Modelo carregado com sucesso.
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:348: InconsistentVersionWarning: Trying to unpickle estimator RandomForestRegressor from version 1.6.0 when using version 1.3.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# ### 4.1. Treino e Predição de modelo base (RF)

# %%
# getting forecasts for the test set
preds = model.predict(X_ts_scaled)

# %%
from sklearn.metrics import mean_absolute_error as mae

# %%
# computing MAE error
print(mae(Y_ts_scaled, preds))
# Out:
# 0.03199597104307796

# %%
# Selecionando os últimos 7 * 24 valores para visualização
last_values = 7 * 24
Y_ts_last = Y_ts_scaled[-last_values:]
preds_last = preds[-last_values:]

# Plotando os últimos valores
plt.figure(figsize=(14, 7))

# Comparando a primeira coluna (ou ajusta conforme a quantidade de targets)
plt.plot(Y_ts_last, label='Valores Reais')
plt.plot(preds_last, label='Previsões', linestyle='--')

plt.title('Predição vs Valores Reais (Últimos 7 dias)')
plt.xlabel('Data')
plt.ylabel('Radiação')
plt.legend()
plt.show()

# %% [markdown]
# ### 4.2. Feature Selection

# %%
# getting importance scores from previous model
importance_scores = pd.Series(dict(zip(X_tr_scaled.columns, model.feature_importances_)))

# getting top n features
n_features = 40
top_n_features = importance_scores.sort_values(ascending=False)[:n_features]
top_n_features_nm = top_n_features.index

X_tr_top = X_tr_scaled[top_n_features_nm]
X_ts_top = X_ts_scaled[top_n_features_nm]

# %%
# show top n features
top_n_features
# Out:
# radiacao_global(t-23)                      0.641278
# radiacao_global(t-0)                       0.195596
# radiacao_global(t-12)                      0.037872
# radiacao_global(t-19)                      0.029742
# radiacao_global(t-20)                      0.015415
# radiacao_global(t-7)                       0.005432
# radiacao_global(t-21)                      0.004792
# radiacao_global(t-11)                      0.004075
# radiacao_global(t-18)                      0.002695
# radiacao_global(t-22)                      0.002198
# radiacao_global(t-1)                       0.001875
# radiacao_global(t-8)                       0.001857
# umidade_relativa_ar_horaria(t-0)           0.001507
# temperatura_ar_bulbo_seco_horaria(t-0)     0.001499
# radiacao_global(t-2)                       0.000964
# radiacao_global(t-24)                      0.000900
# temperatura_ar_bulbo_seco_horaria(t-19)    0.000772
# radiacao_global(t-4)                       0.000763
# radiacao_global(t-6)                       0.000760
# vento_direcao_horaria(t-0)                 0.000758
# vento_direcao_horaria(t-3)                 0.000757
# radiacao_global(t-5)                       0.000691
# vento_direcao_horaria(t-4)                 0.000678
# vento_direcao_horaria(t-22)                0.000658
# vento_direcao_horaria(t-1)                 0.000651
# vento_direcao_horaria(t-24)                0.000641
# radiacao_global(t-3)                       0.000592
# vento_direcao_horaria(t-21)                0.000576
# vento_direcao_horaria(t-23)                0.000574
# vento_direcao_horaria(t-2)                 0.000568
# vento_direcao_horaria(t-19)                0.000554
# vento_direcao_horaria(t-20)                0.000553
# vento_direcao_horaria(t-17)                0.000522
# radiacao_global(t-17)                      0.000519
# vento_direcao_horaria(t-5)                 0.000519
# vento_rajada_maxima(t-0)                   0.000514
# temperatura_ar_bulbo_seco_horaria(t-1)     0.000513
# umidade_relativa_ar_horaria(t-19)          0.000498
# vento_direcao_horaria(t-18)                0.000470
# vento_direcao_horaria(t-6)                 0.000467
# dtype: float64

# %%
# re-fitting the model
model_top_features = RandomForestRegressor()
model_top_features.fit(X_tr_top, Y_tr_scaled.to_numpy().ravel())

# getting forecasts for the test set
preds_topf = model_top_features.predict(X_ts_top)

# computing MAE error
print(mae(Y_ts_scaled, preds_topf))
# Out:
# 0.03157553536266217

# %% [markdown]
# 10 features - MAE 140.08
#
# 20 features - MAE 132.36
#
# 30 features - MAE 131.87
#
# 40 features - MAE 131.23
#
# 50 features - MAE 131.45
#
# 60 features - MAE 132.15
#
# 70 features - MAE 131.61
#
# **OBS.:** Ficaremos com 40 features, resultando no menor MAE. Valores acima para fit sem Min-Max Scaling

# %%
# from joblib import dump

# # Salvar o modelo treinado em um arquivo
# dump(model_top_features, "random_forest_top_features_model.joblib")

# print("Modelo salvo como 'random_forest_top_features_model.joblib'.")
# Out:
# Modelo salvo como 'random_forest_top_features_model.joblib'.

# %% [markdown]
# ### 4.3 Comparação de Modelos de ML tradicionais

# %% [markdown]
# Serão comparados os modelos default:
# 1. KNN Regressor
# 2. SVR
# 3. Random Forest
# 4. XGBoost

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost) (2.23.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.13.1)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
# Lista de modelos com parâmetros default
models = {
    "KNN": KNeighborsRegressor(),
    "SVR": SVR(),
    "Random Forest": RandomForestRegressor(),
    "XGBoost": XGBRegressor()
}

# Dicionário para armazenar as métricas
metrics_results = {}

# %%
# # Função para calcular MAPE
# def mean_absolute_percentage_error(y_true, y_pred):
#     # Converte para numpy arrays, caso necessário
#     y_true = np.asarray(y_true).flatten()
#     y_pred = np.asarray(y_pred).flatten()

#     # Verifica se os tamanhos são compatíveis
#     if len(y_true) != len(y_pred):
#         raise ValueError(f"y_true e y_pred devem ter o mesmo tamanho! Recebido: {len(y_true)} e {len(y_pred)}.")

#     # Filtra os valores de Y_ts onde y_true != 0
#     non_zero_indices = y_true != 0
#     y_true_non_zero = y_true[non_zero_indices]
#     y_pred_non_zero = y_pred[non_zero_indices]

#     # Calcula o MAPE
#     return np.mean(np.abs((y_true_non_zero - y_pred_non_zero) / y_true_non_zero)) * 100

# %%
# Loop pelos modelos
for model_name, model in models.items():
    print(f"Treinando {model_name}...")

    # Treinando o modelo
    model.fit(X_tr_top, Y_tr_scaled.to_numpy().ravel())

    # Prevendo no conjunto de teste
    preds = model.predict(X_ts_top)

    # Calculando as métricas
    mae_val = mean_absolute_error(Y_ts_scaled, preds)
    rmse_val = np.sqrt(mean_squared_error(Y_ts_scaled, preds))
    mape_val = mean_absolute_percentage_error(Y_ts_scaled, preds)

    # Salvando os resultados no dicionário
    metrics_results[model_name] = {
        "MAE": mae_val,
        "RMSE": rmse_val,
        "MAPE": mape_val,
        "Predictions": preds  # Salvando as predições
    }

    print(f"{model_name} - MAE: {mae_val:.4f}, RMSE: {rmse_val:.4f}, MAPE: {mape_val:.2f}%")
# Out:
# Treinando KNN...
# KNN - MAE: 0.0406, RMSE: 0.0769, MAPE: 874179273001.40%
# Treinando SVR...
# SVR - MAE: 0.0481, RMSE: 0.0699, MAPE: 49380858844917.40%
# Treinando Random Forest...
# Random Forest - MAE: 0.0316, RMSE: 0.0634, MAPE: 60497538640.71%
# Treinando XGBoost...
# XGBoost - MAE: 0.0336, RMSE: 0.0660, MAPE: 2161920835584.00%

# %%
# Comparação de resultados
print("\nComparação de Modelos:")
for model, metrics in metrics_results.items():
    print(f"{model}: MAE={metrics['MAE']:.4f}, RMSE={metrics['RMSE']:.4f}, MAPE={metrics['MAPE']:.2f}%")
# Out:
# Comparação de Modelos:
# KNN: MAE=0.0406, RMSE=0.0769, MAPE=874179273001.40%
# SVR: MAE=0.0481, RMSE=0.0699, MAPE=49380858844917.40%
# Random Forest: MAE=0.0316, RMSE=0.0634, MAPE=60497538640.71%
# XGBoost: MAE=0.0336, RMSE=0.0660, MAPE=2161920835584.00%

# %% [markdown]
# ### 4.4. K-fold cross validation

# %%
from sklearn.model_selection import KFold

# Número de folds
n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=False)

# Dicionário para armazenar os resultados
cv_results = {}

# Loop pelos modelos
for model_name, model in models.items():
    print(f"Rodando Cross Validation para {model_name}...")

    # Listas para armazenar as métricas de cada fold
    mae_values, rmse_values, mape_values = [], [], []

    # Loop pelos folds
    for train_index, val_index in kf.split(X_tr_top):
        # Dividindo os dados em treino e validação
        X_train, X_val = X_tr_top.iloc[train_index], X_tr_top.iloc[val_index]
        Y_train, Y_val = Y_tr_scaled.iloc[train_index], Y_tr_scaled.iloc[val_index]

        # Treinando o modelo
        model.fit(X_train, Y_train.to_numpy().ravel())

        # Prevendo no conjunto de validação
        preds = model.predict(X_val)

        # Calculando as métricas
        mae_values.append(mean_absolute_error(Y_val, preds))
        rmse_values.append(np.sqrt(mean_squared_error(Y_val, preds)))
        mape_values.append(mean_absolute_percentage_error(Y_val, preds) * 100)  # MAPE em %

    # Salvando os resultados no dicionário
    cv_results[model_name] = {
        "MAE": mae_values,
        "RMSE": rmse_values,
        "MAPE": mape_values
    }

    print(f"{model_name} - MAE médio: {np.mean(mae_values):.4f}, RMSE médio: {np.mean(rmse_values):.4f}, MAPE médio: {np.mean(mape_values):.2f}%")
# Out:
# Rodando Cross Validation para KNN...
# KNN - MAE médio: 0.0421, RMSE médio: 0.0805, MAPE médio: 110950782279488.03%
# Rodando Cross Validation para SVR...
# SVR - MAE médio: 0.0518, RMSE médio: 0.0749, MAPE médio: 5506392994719060.00%
# Rodando Cross Validation para Random Forest...
# Random Forest - MAE médio: 0.0329, RMSE médio: 0.0660, MAPE médio: 15632481552111.26%
# Rodando Cross Validation para XGBoost...
# XGBoost - MAE médio: 0.0355, RMSE médio: 0.0696, MAPE médio: 329241985024000.00%

# %%
# Criando DataFrame para análise (opcional)
import pandas as pd
cv_summary = pd.DataFrame({
    model_name: {
        "MAE médio": np.mean(metrics["MAE"]),
        "RMSE médio": np.mean(metrics["RMSE"]),
        "MAPE médio (%)": np.mean(metrics["MAPE"])
    }
    for model_name, metrics in cv_results.items()
}).T

print("\nResumo de Cross Validation:")
print(cv_summary)
# Out:
# Resumo de Cross Validation:
#                MAE médio  RMSE médio  MAPE médio (%)
# KNN             0.042150    0.080528    1.109508e+14
# SVR             0.051813    0.074864    5.506393e+15
# Random Forest   0.032944    0.066022    1.563248e+13
# XGBoost         0.035541    0.069590    3.292420e+14

# %%
# Preparar dados para o boxplot de cada métrica
mae_data, mse_data, mape_data = [], [], []

for model_name, metrics in cv_results.items():
    for value in metrics["MAE"]:
        mae_data.append({"Modelo": model_name, "Métrica": "MAE", "Valor": value})
    for value in metrics["RMSE"]:
        mse_data.append({"Modelo": model_name, "Métrica": "RMSE", "Valor": value})
    for value in metrics["MAPE"]:
        mape_data.append({"Modelo": model_name, "Métrica": "MAPE", "Valor": value})

# Converter para DataFrames separados por métrica
mae_df = pd.DataFrame(mae_data)
mse_df = pd.DataFrame(mse_data)
mape_df = pd.DataFrame(mape_data)

# Plotando os 3 gráficos separadamente
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Boxplot para MAE
sns.boxplot(data=mae_df, x="Modelo", y="Valor", hue="Modelo", ax=axs[0])
axs[0].set_title("Boxplot MAE (K-Fold Cross Validation)", fontsize=14)
axs[0].set_xlabel("Modelo", fontsize=12)
axs[0].set_ylabel("MAE", fontsize=12)

# Boxplot para MSE
sns.boxplot(data=mse_df, x="Modelo", y="Valor", hue="Modelo", ax=axs[1])
axs[1].set_title("Boxplot RMSE (K-Fold Cross Validation)", fontsize=14)
axs[1].set_xlabel("Modelo", fontsize=12)
axs[1].set_ylabel("RMSE", fontsize=12)

# Boxplot para MAPE
sns.boxplot(data=mape_df, x="Modelo", y="Valor", hue="Modelo", ax=axs[2])
axs[2].set_title("Boxplot MAPE (K-Fold Cross Validation)", fontsize=14)
axs[2].set_xlabel("Modelo", fontsize=12)
axs[2].set_ylabel("MAPE (%)", fontsize=12)

# Ajustes finais
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.5. Otimização de Hiperparâmetros - Random Forest

# %% [markdown]
# Faremos uma otimização de hiperparâmetros para o melhor modelo segundo as métricas do CrossValidation acima, logo, RandomForest

# %% [markdown]
# #### 4.5.1. Estudo de melhores hiperparâmetros com RandomSearch

# %%
from sklearn.model_selection import RandomizedSearchCV, TimeSeriesSplit

# Definindo os hiperparâmetros e os intervalos
param_dist = {
    'n_estimators': [100, 200, 500, 1000],
    'max_depth': [None, 10, 50, 100],
    'min_samples_split': [2, 5, 10, 15],
    'min_samples_leaf': [1, 5, 10, 20],
    'max_features': ['sqrt', 'log2']
}

# Inicializando o modelo
rf = RandomForestRegressor()

# Configurando TimeSeriesSplit para validação cruzada
tscv = TimeSeriesSplit(n_splits=5)

# Configurando o RandomizedSearchCV
random_search_ts = RandomizedSearchCV(
    estimator=rf,
    param_distributions=param_dist,
    n_iter=50,  # Número de combinaçõess a testar
    scoring='neg_mean_absolute_error',  # Métrica de avaliação
    cv=tscv,  # Validação cruzada com 5 folds com TimeSeriesSplit
    verbose=2,
    # n_jobs=2  # Paralelismo
)

# Executando a busca
random_search_ts.fit(X_tr_top, Y_tr_scaled.to_numpy().ravel())

# Exibindo os melhores parâmetros encontrados
print("Melhores parâmetros do RandomizedSearchCV:")
print(random_search_ts.best_params_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=200; total time=   3.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=200; total time=   7.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=200; total time=  11.7s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=200; total time=  16.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=200; total time=  20.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=   8.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=  15.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=  24.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=  34.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=  43.1s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=  16.2s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=  36.2s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time=  58.9s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time= 1.4min
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=1000; total time= 1.8min
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  25.8s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  58.7s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 1.6min
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 2.2min
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 2.9min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   3.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=   9.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  14.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  20.0s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=200; total time=  26.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=200; total time=   2.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=200; total time=   6.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=200; total time=   8.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=200; total time=  14.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=200; total time=  17.7s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   3.8s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   5.6s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=   9.7s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  12.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=15, n_estimators=200; total time=  15.8s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   3.3s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=   7.2s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=  12.9s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=  18.4s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=200; total time=  23.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=  21.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=  50.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time= 1.3min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time= 1.9min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time= 2.5min
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time=  13.2s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time=  29.8s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time=  46.8s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time= 1.2min
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time= 1.5min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time=  17.0s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time=  39.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time= 1.0min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time= 1.5min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1000; total time= 2.0min
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=   6.9s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=  15.0s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=  23.3s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=  35.0s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=2, n_estimators=500; total time=  44.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   2.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   4.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   6.7s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=  10.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=  13.4s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   7.4s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  17.3s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  25.5s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  38.7s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  49.4s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   1.9s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   4.1s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   5.2s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   9.0s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=100; total time=   9.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  20.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=  44.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time= 1.2min
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time= 1.7min
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time= 2.2min
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   3.5s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=   7.7s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  12.1s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  16.7s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200; total time=  21.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   5.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   9.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  16.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  22.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  28.7s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   1.3s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   3.0s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   5.8s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=   7.4s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=10, min_samples_split=5, n_estimators=100; total time=  10.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time=  15.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time=  34.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time=  57.0s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time= 1.4min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time= 1.8min
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   6.3s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=  14.5s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=  22.9s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=  30.5s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=  37.4s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   3.2s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   5.8s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   9.5s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  12.9s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  17.6s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=100; total time=   1.3s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=100; total time=   2.7s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=100; total time=   4.3s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=100; total time=   7.7s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=100; total time=   8.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   3.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   6.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=   8.7s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=  11.7s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=2, n_estimators=200; total time=  15.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=   9.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=  19.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=  31.6s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=  46.9s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=500; total time=  59.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=500; total time=   7.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=500; total time=  15.9s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=500; total time=  25.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=500; total time=  34.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=500; total time=  43.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=  18.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=  43.0s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time= 1.2min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time= 1.7min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time= 2.1min
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   2.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   5.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=   7.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=  11.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=100; total time=  14.3s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=500; total time=   6.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=500; total time=  13.5s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=500; total time=  21.5s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=500; total time=  29.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=5, n_estimators=500; total time=  36.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=200; total time=   2.6s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=200; total time=   6.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=200; total time=   7.7s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=200; total time=  11.8s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=200; total time=  14.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=   7.9s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  16.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  26.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  38.4s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=10, min_samples_split=10, n_estimators=500; total time=  49.6s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   2.7s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   4.7s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   7.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.8s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=  18.5s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=  36.6s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time=  55.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time= 1.2min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=1000; total time= 1.5min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   1.6s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   3.6s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   7.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   8.6s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=  12.1s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=15, n_estimators=500; total time=   9.4s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=15, n_estimators=500; total time=  19.5s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=15, n_estimators=500; total time=  31.4s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=15, n_estimators=500; total time=  46.0s
# [CV] END max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=15, n_estimators=500; total time=  59.0s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=  17.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=  35.8s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time=  52.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time= 1.2min
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=15, n_estimators=1000; total time= 1.5min
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   2.2s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   4.1s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   5.8s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=   9.8s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=10, n_estimators=100; total time=  12.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=   8.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  23.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  34.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time=  51.8s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=500; total time= 1.1min
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=100; total time=   2.7s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=100; total time=   5.6s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=100; total time=   6.5s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=100; total time=   9.7s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500; total time=   6.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500; total time=  18.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500; total time=  28.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500; total time=  41.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=20, min_samples_split=5, n_estimators=500; total time=  53.9s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=  20.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time=  47.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time= 1.3min
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time= 1.8min
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=15, n_estimators=1000; total time= 2.4min
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=1000; total time=  12.8s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=1000; total time=  29.6s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=1000; total time=  47.9s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=1000; total time= 1.5min
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=1000; total time=  15.3s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=1000; total time=  36.3s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=1000; total time=  57.1s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=1000; total time= 1.4min
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=20, min_samples_split=15, n_estimators=1000; total time= 1.8min
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   2.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   4.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=   6.6s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=  10.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=100; total time=  13.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1000; total time=  16.9s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1000; total time=  39.9s
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1000; total time= 1.1min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1000; total time= 1.5min
# [CV] END max_depth=50, max_features=sqrt, min_samples_leaf=10, min_samples_split=2, n_estimators=1000; total time= 2.0min
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=500; total time=   7.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=500; total time=  13.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=500; total time=  20.7s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=500; total time=  29.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=500; total time=  35.9s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=200; total time=   3.3s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=200; total time=   5.8s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=200; total time=   9.9s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=200; total time=  13.7s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=20, min_samples_split=15, n_estimators=200; total time=  17.8s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   1.6s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   3.6s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   6.8s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=   8.7s
# [CV] END max_depth=100, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=100; total time=  12.2s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   1.5s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   3.4s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   6.7s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=   7.8s
# [CV] END max_depth=100, max_features=log2, min_samples_leaf=5, min_samples_split=5, n_estimators=100; total time=  11.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time=  12.9s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time=  27.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time=  41.8s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time=  57.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=20, min_samples_split=10, n_estimators=1000; total time= 1.2min
# Melhores parâmetros do RandomizedSearchCV:
# {'n_estimators': 1000, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 100}

# %%
# Definir os melhores parâmetros encontrados
# best_params_ts = random_search_ts.best_params_
best_params_ts = {'n_estimators': 1000, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 100}

# Instanciar o modelo com os melhores parâmetros
best_rf_ts = RandomForestRegressor(**best_params_ts)

# Fitar o modelo nos dados de treino
best_rf_ts.fit(X_tr_top, Y_tr_scaled.to_numpy().ravel())
# Out:
# RandomForestRegressor(max_depth=100, max_features='sqrt', n_estimators=1000)

# %%
from joblib import dump

# Salvar o modelo treinado em um arquivo
dump(best_rf_ts, "random_forest_random_search_ts_model.joblib")

print("Modelo salvo como 'random_forest_random_search_ts_model.joblib'.")
# Out:
# Modelo salvo como 'random_forest_random_search_ts_model.joblib'.

# %%
# Fazer previsões no conjunto de teste
y_pred_ts = best_rf_ts.predict(X_ts_top)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# Calcular métricas de avaliação
mae_ts = mean_absolute_error(Y_ts_scaled, y_pred_ts)
rmse_ts = np.sqrt(mean_squared_error(Y_ts_scaled, y_pred_ts))
mape_ts = mean_absolute_percentage_error(Y_ts_scaled, y_pred_ts) * 100

# Exibir as métricas
print(f"MAE: {mae_ts}")
print(f"RMSE: {rmse_ts}")
print(f"MAPE: {mape_ts}%")
# Out:
# MAE: 0.03222779779054468
# RMSE: 0.06286843576125223
# MAPE: 37749701943792.7%

# %%
# Selecionando os últimos 7 * 24 valores para visualização
last_values = 7 * 24
Y_ts_last = Y_ts_scaled[-last_values:]
preds_rf_ts_last = y_pred_ts[-last_values:]

# Plotando os últimos valores
plt.figure(figsize=(14, 7))

# Comparando a primeira coluna (ou ajusta conforme a quantidade de targets)
plt.plot(Y_ts_last, label='Valores Reais')
plt.plot(preds_rf_ts_last, label='Previsões', linestyle='--')

# plt.title('Predição vs Valores Reais (Últimos 7 dias)')
plt.xlabel('Data')
plt.ylabel('Radiação')
plt.legend()
plt.show()

# %% [markdown]
# ### 4.6. Otimização de Hiperparâmetros - XGBoost

# %% [markdown]
# Faremos uma otimização de hiperparâmetros para o melhor modelo segundo as métricas do CrossValidation acima, logo, XGBoost

# %% [markdown]
# #### 4.6.1. Estudo de melhores hiperparâmetros com RandomSearch

# %%
# !pip uninstall -y scikit-learn
# !pip install scikit-learn==1.3.1
# Out:
# Found existing installation: scikit-learn 1.6.0
# Uninstalling scikit-learn-1.6.0:
#   Successfully uninstalled scikit-learn-1.6.0
# Collecting scikit-learn==1.3.1
#   Downloading scikit_learn-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.1) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.1) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.1) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.1) (3.5.0)
# Downloading scikit_learn-1.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 62.4 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.3.1 which is incompatible.
# Successfully installed scikit-learn-1.3.1

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import RandomizedSearchCV, TimeSeriesSplit

# Definindo os hiperparâmetros e os intervalos

param_dist_xgboost = {
    "n_estimators": [100, 200, 300, 400, 500],       # Evita valores muito baixos
    "learning_rate": [0.01, 0.05, 0.1, 0.2],         # Taxas de aprendizado comuns
    "max_depth": [3, 5, 7, 10],                      # Evita profundidades extremas
    "subsample": [0.6, 0.7, 0.8, 0.9],               # Amostragem mais controlada
    "colsample_bytree": [0.6, 0.7, 0.8, 0.9],        # Similar ao subsample
    "gamma": [0, 1, 2, 3],                           # Regularização básica
    "min_child_weight": [1, 3, 5, 7],                # Regularização adicional
    "reg_alpha": [0, 0.1, 0.5, 1, 5],                # Evita valores muito altos
    "reg_lambda": [0.1, 0.5, 1, 2, 5]                # Foco em regularização leve
}

# Inicializando o modelo
xgb_model = XGBRegressor(objective='reg:squarederror', random_state=42)

# Configurando TimeSeriesSplit para validação cruzada
tscv = TimeSeriesSplit(n_splits=5)

# Configurando o RandomizedSearchCV
random_search_xgb = RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=param_dist_xgboost,
    n_iter=50,  # Número de combinaçõess a testar
    scoring='neg_mean_absolute_error',  # Métrica de avaliação
    cv=tscv,  # Validação cruzada com 5 folds com TimeSeriesSplit
    verbose=2,
    # n_jobs=2  # Paralelismo
    random_state=42  # Semente para reprodutibilidade
)

# Executando a busca
random_search_xgb.fit(X_tr_top, Y_tr_scaled.to_numpy().ravel())

# Exibindo os melhores parâmetros encontrados
print("Melhores parâmetros do RandomizedSearchCV:")
print(random_search_xgb.best_params_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.2, max_depth=3, min_child_weight=7, n_estimators=500, reg_alpha=0.5, reg_lambda=5, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.2, max_depth=3, min_child_weight=7, n_estimators=500, reg_alpha=0.5, reg_lambda=5, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.2, max_depth=3, min_child_weight=7, n_estimators=500, reg_alpha=0.5, reg_lambda=5, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.2, max_depth=3, min_child_weight=7, n_estimators=500, reg_alpha=0.5, reg_lambda=5, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.2, max_depth=3, min_child_weight=7, n_estimators=500, reg_alpha=0.5, reg_lambda=5, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.9; total time=   1.9s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.9; total time=   2.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.9; total time=   4.7s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.9; total time=   4.7s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.9; total time=   3.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=500, reg_alpha=0.1, reg_lambda=2, subsample=0.6; total time=   2.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=500, reg_alpha=0.1, reg_lambda=2, subsample=0.6; total time=   4.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=500, reg_alpha=0.1, reg_lambda=2, subsample=0.6; total time=   5.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=500, reg_alpha=0.1, reg_lambda=2, subsample=0.6; total time=   3.6s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=500, reg_alpha=0.1, reg_lambda=2, subsample=0.6; total time=   4.2s
# [CV] END colsample_bytree=0.8, gamma=3, learning_rate=0.05, max_depth=7, min_child_weight=7, n_estimators=400, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=3, learning_rate=0.05, max_depth=7, min_child_weight=7, n_estimators=400, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.8, gamma=3, learning_rate=0.05, max_depth=7, min_child_weight=7, n_estimators=400, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=3, learning_rate=0.05, max_depth=7, min_child_weight=7, n_estimators=400, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=3, learning_rate=0.05, max_depth=7, min_child_weight=7, n_estimators=400, reg_alpha=0.1, reg_lambda=5, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=5, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=5, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=5, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=5, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, reg_alpha=1, reg_lambda=5, subsample=0.8; total time=   4.5s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   1.8s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=300, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   0.9s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=400, reg_alpha=5, reg_lambda=2, subsample=0.6; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=400, reg_alpha=5, reg_lambda=2, subsample=0.6; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=400, reg_alpha=5, reg_lambda=2, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=400, reg_alpha=5, reg_lambda=2, subsample=0.6; total time=   1.0s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.05, max_depth=10, min_child_weight=7, n_estimators=400, reg_alpha=5, reg_lambda=2, subsample=0.6; total time=   2.4s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=400, reg_alpha=5, reg_lambda=0.5, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=400, reg_alpha=5, reg_lambda=0.5, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=400, reg_alpha=5, reg_lambda=0.5, subsample=0.8; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=400, reg_alpha=5, reg_lambda=0.5, subsample=0.8; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=400, reg_alpha=5, reg_lambda=0.5, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   4.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=  10.6s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   2.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   1.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=0.1, reg_lambda=5, subsample=0.7; total time=   1.7s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0.1, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0.1, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0.1, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0.1, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0.1, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.9s
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   3.0s
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.2s
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=1, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=0.8; total time=   1.5s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=500, reg_alpha=5, reg_lambda=5, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=500, reg_alpha=5, reg_lambda=5, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=500, reg_alpha=5, reg_lambda=5, subsample=0.8; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=500, reg_alpha=5, reg_lambda=5, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=5, n_estimators=500, reg_alpha=5, reg_lambda=5, subsample=0.8; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=   0.5s
# [CV] END colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=   2.4s
# [CV] END colsample_bytree=0.8, gamma=3, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=400, reg_alpha=1, reg_lambda=1, subsample=0.9; total time=   2.9s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   5.7s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=  10.9s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=   9.4s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=  15.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=500, reg_alpha=1, reg_lambda=1, subsample=0.6; total time=  14.7s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=300, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=300, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=300, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=300, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   2.1s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.05, max_depth=10, min_child_weight=5, n_estimators=300, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   3.3s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.1, reg_lambda=2, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.1, reg_lambda=2, subsample=0.9; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.1, reg_lambda=2, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.1, reg_lambda=2, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.2, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.1, reg_lambda=2, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, reg_alpha=1, reg_lambda=0.5, subsample=0.9; total time=   3.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, reg_alpha=1, reg_lambda=0.5, subsample=0.9; total time=   8.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, reg_alpha=1, reg_lambda=0.5, subsample=0.9; total time=   6.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, reg_alpha=1, reg_lambda=0.5, subsample=0.9; total time=  11.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, reg_alpha=1, reg_lambda=0.5, subsample=0.9; total time=  12.7s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=5, reg_lambda=1, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=5, reg_lambda=1, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=5, reg_lambda=1, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=5, reg_lambda=1, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=1, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=100, reg_alpha=5, reg_lambda=1, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.05, max_depth=3, min_child_weight=5, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6; total time=   3.7s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6; total time=   1.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=2, subsample=0.7; total time=  17.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=2, subsample=0.7; total time=  23.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=2, subsample=0.7; total time=  25.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=2, subsample=0.7; total time=  35.7s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=500, reg_alpha=0, reg_lambda=2, subsample=0.7; total time=  38.5s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   1.2s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   4.6s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   2.2s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=400, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   2.1s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.9; total time=   1.8s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, reg_alpha=0.1, reg_lambda=0.5, subsample=0.9; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   2.3s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, reg_alpha=1, reg_lambda=1, subsample=0.7; total time=   2.9s
# [CV] END colsample_bytree=0.7, gamma=3, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=3, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=3, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=3, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=3, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=300, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=100, reg_alpha=0.5, reg_lambda=0.1, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   2.8s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   6.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   3.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   3.9s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   7.7s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   1.2s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   1.4s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=5, n_estimators=400, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   1.7s
# [CV] END colsample_bytree=0.7, gamma=3, learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=300, reg_alpha=5, reg_lambda=5, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=3, learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=300, reg_alpha=5, reg_lambda=5, subsample=0.6; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=3, learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=300, reg_alpha=5, reg_lambda=5, subsample=0.6; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=3, learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=300, reg_alpha=5, reg_lambda=5, subsample=0.6; total time=   1.0s
# [CV] END colsample_bytree=0.7, gamma=3, learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=300, reg_alpha=5, reg_lambda=5, subsample=0.6; total time=   4.0s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, reg_alpha=1, reg_lambda=5, subsample=0.6; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, reg_alpha=1, reg_lambda=5, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, reg_alpha=1, reg_lambda=5, subsample=0.6; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, reg_alpha=1, reg_lambda=5, subsample=0.6; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=2, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=200, reg_alpha=1, reg_lambda=5, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=1, learning_rate=0.2, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=1, reg_lambda=5, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=5, n_estimators=500, reg_alpha=0.5, reg_lambda=1, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=7, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=7, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   4.8s
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=7, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   1.6s
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=7, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   2.2s
# [CV] END colsample_bytree=0.9, gamma=1, learning_rate=0.01, max_depth=7, min_child_weight=7, n_estimators=500, reg_alpha=0, reg_lambda=1, subsample=0.7; total time=   2.6s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.5, reg_lambda=1, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.5, reg_lambda=1, subsample=0.6; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.5, reg_lambda=1, subsample=0.6; total time=   0.5s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.5, reg_lambda=1, subsample=0.6; total time=   0.6s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=200, reg_alpha=0.5, reg_lambda=1, subsample=0.6; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=5, reg_lambda=2, subsample=0.9; total time=   2.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=5, reg_lambda=2, subsample=0.9; total time=   4.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=5, reg_lambda=2, subsample=0.9; total time=   2.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=5, reg_lambda=2, subsample=0.9; total time=   2.5s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=5, reg_lambda=2, subsample=0.9; total time=   2.7s
# [CV] END colsample_bytree=0.9, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=2, subsample=0.6; total time=   0.5s
# [CV] END colsample_bytree=0.9, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=2, subsample=0.6; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=2, subsample=0.6; total time=   4.5s
# [CV] END colsample_bytree=0.9, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=2, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.9, gamma=3, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=2, subsample=0.6; total time=   1.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0.5, reg_lambda=2, subsample=0.6; total time=   0.7s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0.5, reg_lambda=2, subsample=0.6; total time=   0.9s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0.5, reg_lambda=2, subsample=0.6; total time=   1.1s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0.5, reg_lambda=2, subsample=0.6; total time=   1.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=300, reg_alpha=0.5, reg_lambda=2, subsample=0.6; total time=   1.4s
# [CV] END colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=5, reg_lambda=0.5, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=5, reg_lambda=0.5, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=5, reg_lambda=0.5, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=5, reg_lambda=0.5, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.9, gamma=3, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=5, reg_lambda=0.5, subsample=0.8; total time=   1.8s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   5.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   4.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   7.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   5.9s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.2, max_depth=7, min_child_weight=3, n_estimators=300, reg_alpha=0.1, reg_lambda=1, subsample=0.8; total time=   5.6s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8; total time=   1.6s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8; total time=   1.3s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.8, gamma=2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=5, reg_lambda=0.1, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=5, reg_lambda=0.1, subsample=0.7; total time=   0.6s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=5, reg_lambda=0.1, subsample=0.7; total time=   0.8s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=5, reg_lambda=0.1, subsample=0.7; total time=   1.0s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=200, reg_alpha=5, reg_lambda=0.1, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   1.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   1.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=7, min_child_weight=7, n_estimators=100, reg_alpha=0, reg_lambda=0.1, subsample=0.9; total time=   5.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   0.6s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   0.7s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.9; total time=   1.7s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.9; total time=   7.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.9; total time=   2.9s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.9; total time=   2.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=300, reg_alpha=0.5, reg_lambda=0.5, subsample=0.9; total time=   2.6s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   0.8s
# [CV] END colsample_bytree=0.6, gamma=3, learning_rate=0.2, max_depth=5, min_child_weight=7, n_estimators=400, reg_alpha=0.5, reg_lambda=2, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.8; total time=   2.5s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.8; total time=   2.6s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.8; total time=   1.4s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.8; total time=   1.7s
# [CV] END colsample_bytree=0.9, gamma=2, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=400, reg_alpha=1, reg_lambda=0.5, subsample=0.8; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7; total time=   0.7s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7; total time=   0.9s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7; total time=   2.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=500, reg_alpha=5, reg_lambda=0.1, subsample=0.7; total time=   3.7s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=500, reg_alpha=5, reg_lambda=0.1, subsample=0.7; total time=   1.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=500, reg_alpha=5, reg_lambda=0.1, subsample=0.7; total time=   1.6s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=500, reg_alpha=5, reg_lambda=0.1, subsample=0.7; total time=   1.8s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=500, reg_alpha=5, reg_lambda=0.1, subsample=0.7; total time=   2.1s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.5, reg_lambda=2, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.5, reg_lambda=2, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.5, reg_lambda=2, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.5, reg_lambda=2, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=2, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.5, reg_lambda=2, subsample=0.8; total time=   0.6s
# Melhores parâmetros do RandomizedSearchCV:
# {'subsample': 0.9, 'reg_lambda': 0.1, 'reg_alpha': 0, 'n_estimators': 100, 'min_child_weight': 7, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 0, 'colsample_bytree': 0.7}

# %%
# Definir os melhores parâmetros encontrados
# best_params_ts = random_search_ts.best_params_
best_params_xgb = random_search_xgb.best_params_

# Instanciar o modelo com os melhores parâmetros
best_xgb = XGBRegressor(**best_params_xgb)

# Fitar o modelo nos dados de treino
best_xgb.fit(X_tr_top, Y_tr_scaled.to_numpy().ravel())
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=7, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
from joblib import dump

# Salvar o modelo treinado em um arquivo
dump(best_xgb, "xgb_random_search_model.joblib")

print("Modelo salvo como 'xgb_random_search_model.joblib'.")
# Out:
# Modelo salvo como 'xgb_random_search_model.joblib'.

# %%
# Fazer previsões no conjunto de teste
y_pred_xgb = best_xgb.predict(X_ts_top)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# Calcular métricas de avaliação
mae_xgb = mean_absolute_error(Y_ts_scaled, y_pred_xgb)
rmse_xgb = np.sqrt(mean_squared_error(Y_ts_scaled, y_pred_xgb))
mape_xgb = mean_absolute_percentage_error(Y_ts_scaled, y_pred_xgb) * 100

# Exibir as métricas
print(f"MAE: {mae_xgb}")
print(f"RMSE: {rmse_xgb}")
print(f"MAPE: {mape_xgb}%")
# Out:
# MAE: 0.03169785613302116
# RMSE: 0.06309529687619139
# MAPE: 83743832917714.88%

# %%
# Selecionando os últimos 7 * 24 valores para visualização
last_values = 7 * 24
Y_ts_last = Y_ts_scaled[-last_values:]
preds_xgb_last = y_pred_xgb[-last_values:]

# Plotando os últimos valores
plt.figure(figsize=(14, 7))

# Comparando a primeira coluna (ou ajusta conforme a quantidade de targets)
plt.plot(Y_ts_last, label='Valores Reais')
plt.plot(preds_xgb_last, label='Previsões', linestyle='--')

# plt.title('Predição vs Valores Reais (Últimos 7 dias)')
plt.xlabel('Data')
plt.ylabel('Radiação')
plt.legend()
plt.show()
